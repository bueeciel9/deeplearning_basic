# %% [markdown]
# #1. Linear Function and Regression

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
Tortoise_Speed = 1 #@param {type:"slider", min:0, max:10, step: 1}
Tortoise_Bias = 4 #@param {type:"slider", min:0, max:10, step: 1}
Hare_Speed = 2 #@param {type:"slider", min:0, max:10, step: 1}

MAXVAL = 10
INTERVAL = (MAXVAL*10) + 1
doMeet = False
t_xdata, t_ydata, h_xdata, h_ydata = [], [], [], []

# %%
#Configure figure size
plt.figure(figsize=(10,10))

for t in np.linspace(0, MAXVAL, INTERVAL):
    t_y = Tortoise_Speed*t + Tortoise_Bias
    h_y = Hare_Speed*t
    t_xdata.append(t)
    t_ydata.append(t_y)
    h_xdata.append(t)
    h_ydata.append(h_y)
    if(h_y >= t_y and (not doMeet)):
        doMeet = True
        meetTime = t
        meetDistance = t_y

plt.plot(t_xdata, t_ydata, label='Tortoise')
plt.plot(h_xdata, h_ydata, label='Hare')

if (doMeet):
    plt.title('The hare overcomed from '+str(math.ceil(meetTime*100)/100)+'hour(s), '+str(math.ceil(meetDistance*100)/100)+'km(s)', fontsize=16)
    plt.plot(meetTime, meetDistance, 'ro')
else:
    plt.title('They will not meet', fontsize=16)

plt.xlabel('Time(hour)', fontsize=14)
plt.ylabel('Distance(km)', fontsize=14)
plt.legend()
#Show plot
plt.show()

# %% [markdown]
# #2. Tensorflow

# %%
import tensorflow as tf

# %%
learning_rate = 0.01
learning_epochs = 100

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim=1))

# Stochastic gradient descent (SGD) Optimizer
sgd = tf.keras.optimizers.SGD(learning_rate=learning_rate)
# Mean Square Error (MSE) loss function
mse = tf.keras.losses.mean_squared_error
model.compile(loss='mse', optimizer=sgd)

# %%
# prints summary of the model to the terminal
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #3. Prediction
#
# Tortoise
#
# Hare

# %%
# Train the model
history = model.fit(t_xdata, t_ydata, epochs=learning_epochs)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 95.0197
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.3212
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.1746
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.1067
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.1281
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7591
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6856
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6801
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6683
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4962
# Epoch 11/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2215
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4081
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2068
# Epoch 14/100
# 4/4 [==============================] - 0s 1ms/step - loss: 2.0818
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9304
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9467
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8399
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7876
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0520
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7884
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6080
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4837
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4513
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4553
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2740
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2905
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2451
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1304
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0803
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1810
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1356
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0297
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9171
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8484
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8541
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8044
# Epoch 37/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8138
# Epoch 38/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8819
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7569
# Epoch 40/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7562
# Epoch 41/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6879
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6447
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6124
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5950
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5786
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5576
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5544
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4754
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4441
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5136
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4596
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4278
# Epoch 53/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4271
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4062
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4077
# Epoch 56/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3777
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3740
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3526
# Epoch 59/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3127
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3225
# Epoch 61/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3251
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2938
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2925
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2771
# Epoch 65/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2672
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2575
# Epoch 67/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2667
# Epoch 68/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2312
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2174
# Epoch 70/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2314
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2133
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2094
# Epoch 73/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1972
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1816
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1708
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1662
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1731
# Epoch 78/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1529
# Epoch 79/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1612
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1433
# Epoch 81/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1351
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1295
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1193
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1341
# Epoch 85/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1308
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1148
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1059
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0984
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0946
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1043
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0903
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0929
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0864
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0809
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0795
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0836
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0714
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0690
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0659
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0678

# %%
plt.plot(history.history['loss'])
plt.show()

# %%
model.predict([10])
# Out:
# array([[14.285066]], dtype=float32)

# %%
p_ydata = model.predict(t_xdata)

# %%
#Configure figure size
plt.figure(figsize=(10,10))

plt.plot(t_xdata, t_ydata, 'r*')
plt.plot(t_xdata, p_ydata, color='b')
plt.show()
