# %% [markdown]
# Copyright 2019 The TensorFlow Authors.
#
# Copyright 2020 The creApple Authors.

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import math

print(tf.__version__)
# Out:
# 2.4.1

# %%
# Define Constants
batch_size = 128
epochs = 100
num_classes = 10

# %%
# Download MNIST dataset.
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
len(train_images), len(test_images)
# Out:
# (60000, 10000)

# %%
# Normalize the input image so that each pixel value is between 0 to 1.
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Define the model architecture
model = keras.Sequential([
                         keras.layers.Flatten(input_shape=(28,28)),
                         keras.layers.Dense(128, activation=tf.nn.relu),
                         keras.layers.Dense(num_classes, activation='softmax')
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6288 - accuracy: 0.8286
# Epoch 2/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1844 - accuracy: 0.9482
# Epoch 3/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1245 - accuracy: 0.9636
# Epoch 4/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0963 - accuracy: 0.9720
# Epoch 5/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0788 - accuracy: 0.9773
# Epoch 6/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0597 - accuracy: 0.9831
# Epoch 7/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0532 - accuracy: 0.9857
# Epoch 8/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0435 - accuracy: 0.9879
# Epoch 9/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0368 - accuracy: 0.9900
# Epoch 10/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0312 - accuracy: 0.9913
# Epoch 11/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0260 - accuracy: 0.9930
# Epoch 12/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0231 - accuracy: 0.9945
# Epoch 13/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0209 - accuracy: 0.9945
# Epoch 14/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0164 - accuracy: 0.9961
# Epoch 15/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0143 - accuracy: 0.9966
# Epoch 16/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0111 - accuracy: 0.9979
# Epoch 17/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0104 - accuracy: 0.9979
# Epoch 18/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0088 - accuracy: 0.9980
# Epoch 19/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0082 - accuracy: 0.9985
# Epoch 20/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0083 - accuracy: 0.9982
# Epoch 21/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0052 - accuracy: 0.9994
# Epoch 22/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0052 - accuracy: 0.9992
# Epoch 23/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0053 - accuracy: 0.9992
# Epoch 24/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0032 - accuracy: 0.9997
# Epoch 25/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0029 - accuracy: 0.9998
# Epoch 26/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0026 - accuracy: 0.9998
# Epoch 27/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0095 - accuracy: 0.9974
# Epoch 28/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9990
# Epoch 29/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 30/100
# 469/469 [==============================] - 2s 3ms/step - loss: 9.2224e-04 - accuracy: 1.0000
# Epoch 31/100
# 469/469 [==============================] - 2s 3ms/step - loss: 8.3931e-04 - accuracy: 1.0000
# Epoch 32/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 33/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0103 - accuracy: 0.9965
# Epoch 34/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 35/100
# 469/469 [==============================] - 2s 3ms/step - loss: 7.2494e-04 - accuracy: 1.0000
# Epoch 36/100
# 469/469 [==============================] - 2s 3ms/step - loss: 4.8645e-04 - accuracy: 1.0000
# Epoch 37/100
# 469/469 [==============================] - 2s 3ms/step - loss: 4.1335e-04 - accuracy: 1.0000
# Epoch 38/100
# 469/469 [==============================] - 2s 3ms/step - loss: 4.0540e-04 - accuracy: 1.0000
# Epoch 39/100
# 469/469 [==============================] - 2s 3ms/step - loss: 3.4787e-04 - accuracy: 1.0000
# Epoch 40/100
# 469/469 [==============================] - 2s 3ms/step - loss: 3.2620e-04 - accuracy: 1.0000
# Epoch 41/100
# 469/469 [==============================] - 2s 3ms/step - loss: 2.9315e-04 - accuracy: 1.0000
# Epoch 42/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.
100
# 469/469 [==============================] - 2s 3ms/step - loss: 1.8923e-05 - accuracy: 1.0000
# Epoch 99/100
# 469/469 [==============================] - 2s 3ms/step - loss: 1.6729e-05 - accuracy: 1.0000
# Epoch 100/100
# 469/469 [==============================] - 2s 4ms/step - loss: 2.1746e-05 - accuracy: 1.0000

# %%
# Evaluate the model using test dataset.
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test Accuracy: ', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1245 - accuracy: 0.9803
# Test Accuracy:  0.9803000092506409

# %%
# Helper function to display digit images
def show_sample(images, labels, sample_count=25):
  # Create a square with can fit {sample_count} images
  grid_count = math.ceil(math.ceil(math.sqrt(sample_count)))
  grid_count = min(grid_count, len(images), len(labels))
  
  plt.figure(figsize=(2*grid_count, 2*grid_count))
  for i in range(sample_count):
    plt.subplot(grid_count, grid_count, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i], cmap=plt.cm.gray)
    plt.xlabel(labels[i])
  plt.show()

# Helper function to display specific digit images
def show_sample_digit(images, labels, digit, sample_count=25):
  # Create a square with can fit {sample_count} images
  grid_count = math.ceil(math.ceil(math.sqrt(sample_count)))
  grid_count = min(grid_count, len(images), len(labels))
  
  plt.figure(figsize=(2*grid_count, 2*grid_count))
  i = 0
  digit_count = 0
  while digit_count < sample_count:
    i += 1
    if (digit == labels[i]):
      plt.subplot(grid_count, grid_count, digit_count+1)
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)
      plt.imshow(images[i], cmap=plt.cm.gray)
      plt.xlabel(labels[i])
      digit_count += 1
  plt.show()

# Helper function to display specific digit images
def show_digit_image(image):
  # Draw digit image
  fig = plt.figure()
  ax = fig.add_subplot(1, 1, 1)
  # Major ticks every 20, minor ticks every 5
  major_ticks = np.arange(0, 29, 5)
  minor_ticks = np.arange(0, 29, 1)
  ax.set_xticks(major_ticks)
  ax.set_xticks(minor_ticks, minor=True)
  ax.set_yticks(major_ticks)
  ax.set_yticks(minor_ticks, minor=True)
  # And a corresponding grid
  ax.grid(which='both')
  # Or if you want different settings for the grids:
  ax.grid(which='minor', alpha=0.2)
  ax.grid(which='major', alpha=0.5)
  ax.imshow(image, cmap=plt.cm.binary)

  plt.show()

# %%
# Show the first 25 images in the training dataset.
show_sample(test_images, ['Label: %s' % label for label in test_labels])

# %%
# Show digit 7 the first 25 images in the training dataset.
show_sample_digit(train_images, train_labels, 7)

# %%
# Evaluate the model using test dataset. - Show performance

fig, loss_ax = plt.subplots()
fig, acc_ax = plt.subplots()

loss_ax.plot(history.history['loss'], 'ro')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')

acc_ax.plot(history.history['accuracy'], 'bo')
acc_ax.set_xlabel('epoch')
acc_ax.set_ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
# Predict the labels of digit images in our test dataset.
predictions = model.predict(test_images)

# Then plot the first 25 test images and their predicted labels.
show_sample(test_images, ['Predicted: %d ' % np.argmax(result) for result in predictions])

# %%
Digit = 8448 #@param {type:"slider", min:1, max:10000, step:1}
selected_digit = Digit - 1

result = predictions[selected_digit]
result_number = np.argmax(result)
print('Number is %2d' % result_number)

show_digit_image(test_images[selected_digit])
# Out:
# Number is  5
