98\xc9\x14\xe6]\xd4\x0c\x8fy\xf4\xa3h\xf5\xa7~\x14l\xa8\xb1\\\xa36\xfb\xd1\xb6\xa4)\xc6sJ\x17\x1c\xe6\xac\xce\xd6\x18SwZB8\xc5H\xd4\xaa\x95c\x18\xa0/zF\x00\xf7\xa7:g\x91B&95\x05\xdc\x88\x8c\x1cR\x85=\xf8\xa7\x91A_J\x05r<\x1a0i\xfb\x0f\xa5\x1b\x0f\xa5U\xc2\xe3\x00\'\xa5\x04\x11\xd6\x9d\x82:qG=\xcej.U\xd0\xd2\xbf-\t\xd2\xa5\xc7je\x17\x0b\x05#S\xb6\x9fJ]\xa4v\xa6":6T\x9eX\xf6\xfc\xe8d+@j7\x1bi\xb5"\x80O4\xda\x00\x8f\x9ap\\\xad:\x95\x13\xe6\xc1\xa0\x06m\xdbEHS\xf1\xa4\xdb\x8e\xd4\xc0e\x14\xean\r\x17\x00U\xa1\x96\x9c\x06(#57\x15\xc6lo\xf2(\xd8\xdf\xe4S\xe8\xc7\xbd1\x91\x948\xa1T\x83R\xecoZO,\x8e\xbd(\x05\xb8\xda*\\\xd1Ac\n`g4\xdc.}j\\\xd4{9\xe2\x80\x12\x8c{S\xa8\xa83\xb9\x1f\x92s\x9cS\xaa\\\xd2\x18\xc7\xa5Y\xa1\x11\x19\xa4\x034\xfd\xb4m\xac\xf53\xb8\xcd\xa6\x8d\xa6\xa4\xd8iX\x16\xad\r\x08\xf6\xd3j]\x86\x93\xcb\xf7\xa0\x08\xe93\xedRyF\x93\x00P\x03qJ\xd5&\xd1\xefH\xc3\x1d\xf3@\x11\x11\xcd.\xde\x94\xecs\x9aZ9\x90\x93\xb8\xd2:\x01Q]\\\xc7g\x13I+\x00\xa0d\x9a\x8bS\xd5`\xd2\xa2W\x9d\xb6\x06;W\xdc\xd7\x9f\xdejW>.\x9e\xe2\'cm\x1cY\x00\xa3p\xdfPk\x87\x11\x8aT\x96\x9b\x9d\xb4h{ ...

# %%
# !ls -al
# Out:
# total 80
# drwxr-xr-x 1 root root  4096 Mar 12 09:40 .
# drwxr-xr-x 1 root root  4096 Mar 12 09:29 ..
# -rw-r--r-- 1 root root 63506 Mar 12 09:40 car3.jpeg
# drwxr-xr-x 4 root root  4096 Mar  5 14:36 .config
# drwxr-xr-x 1 root root  4096 Mar  5 14:37 sample_data

# %%
import cv2
import numpy as np
import math
from google.colab.patches import cv2_imshow

# %%
file_name = 'car3.jpeg'
frame = cv2.imread(file_name)
cv2_imshow(frame)
height, width, channels = frame.shape
print(height, width, channels)
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x7F5DA1FCEAD0>
# 540 960 3

# %%
# Conver the image to grayscale
gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
cv2_imshow(gray)
height, width = gray.shape
print(height, width)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F5DAB815C50>
# 540 960

# %%
# GaussianBlur for refucing noise
blur = cv2.GaussianBlur(gray, (5, 5), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F5DA1FCE590>

# %%
canny = cv2.Canny(blur, 40, 130)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F5DA16EAB50>

# %% [markdown]
# #2. Region of Interest

# %%
mask = np.zeros((height,width), dtype='uint8')
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F5DA16F15D0>

# %%
poly_heigh = int(0.60 * height)
poly_left = int(0.47 * width)
poly_right = int(0.53 * width)
polygons = np.array([[(0,height), (poly_left, poly_heigh), (poly_right, poly_heigh), (width, height)]])
cv2.fillPoly(mask, polygons, 255)
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F5DA16F1C90>

# %%
# Bitwise operation between poly and mask
masked = cv2.bitwise_and(canny, mask)
cv2_imshow(masked)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F5DA16EA990>

# %% [markdown]
# #3. Lane Detection

# %%
lines = cv2.HoughLinesP(masked, 2, np.pi / 180, 20, np.array([]), 20, 10)

# %%
image_rgb = cv2.cvtColor(canny, cv2.COLOR_GRAY2RGB)
if lines is not None:
    for line in lines:
        print(line)
        x1, y1, x2, y2 = line.reshape(4)
        cv2.line(image_rgb, (x1, y1), (x2, y2), (0, 0, 255), 1)
    cv2_imshow(image_rgb)
# Out:
# [[712 460 832 538]]
# [[515 327 853 538]]
# [[505 324 719 463]]
# [[310 422 355 392]]
# [[331 417 362 394]]
# [[406 357 453 324]]
# [[409 359 439 339]]
# [[651 420 717 462]]
# [[318 425 363 392]]
# [[310 423 358 392]]
# [[706 456 738 476]]
# [[408 359 459 324]]
# [[410 359 430 346]]
# [[164 522 187 521]]
# [[506 325 680 438]]
# [[409 356 455 324]]
# [[426 346 457 324]]
# <PIL.Image.Image image mode=RGB size=960x540 at 0x7F5DA14E5350>

# %%
for line in lines:
    for x1, y1, x2, y2 in line:
        cv2.line(frame, (x1, y1), (x2, y2), (0, 255, 255), 5)
cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x7F5DA166D550>
