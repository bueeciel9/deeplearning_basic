# %% [markdown]
# #1. Open API
#
# 실시간 영업소간 통행시간
#
# http://data.ex.co.kr/openapi/trtm/realUnitTrtm

# %%
import requests

# %%
key = 'YOUR KEY'
type = 'json'
StartUnitCode = '101'
EndUnitCode = '103'

URL = 'http://data.ex.co.kr/openapi/trtm/realUnitTrtm?key='
url = URL + key + '&type=json&iStartUnitCode=' + StartUnitCode + '&iEndUnitCode=' + EndUnitCode

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
json = response.json()

# %%
json
# Out:
# {'code': 'SUCCESS',
#  'count': 1312,
#  'message': '인증키가 유효합니다.',
#  'numOfRows': 10,
#  'pageNo': 1,
#  'pageSize': 132,
#  'realUnitTrtmVO': [{'efcvTrfl': '49',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '12:50',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '13.316666666666666',
#    'timeMax': '16.333',
#    'timeMin': '8.150'},
#   {'efcvTrfl': '49',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '12:55',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '12.45',
#    'timeMax': '11.783',
#    'timeMin': '8.683'},
#   {'efcvTrfl': '642',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13  ',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '8.783333333333333',
#    'timeMax': '13.300',
#    'timeMin': '6.466'},
#   {'efcvTrfl': '192',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13:00',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '12.35',
#    'timeMax': '13.300',
#    'timeMin': '6.466'},
#   {'efcvTrfl': '61',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13:05',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '11.383333333333333',
#    'timeMax': '13.300',
#    'timeMin': '7.450'},
#   {'efcvTrfl': '53',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13:10',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '10.533333333333333',
#    'timeMax': '10.933',
#    'timeMin': '6.466'},
#   {'efcvTrfl': '178',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13:15',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '10.575',
#    'timeMax': '10.683',
#    'timeMin': '7.150'},
#   {'efcvTrfl': '42',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13:20',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '9.466666666666667',
#    'timeMax': '10.683',
#    'timeMin': '7.150'},
#   {'efcvTrfl': '54',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13:25',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '9.25',
#    'timeMax': '10.583',
#    'timeMin': '7.350'},
#   {'efcvTrfl': '236',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210130',
#    'stdTime': '13:30',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '10.0',
#    'timeMax': '12.050',
#    'timeMin': '8.250'}]}

# %%
cars = json['realUnitTrtmVO']

# %%
cars
# Out:
# [{'efcvTrfl': '49',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '12:50',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '13.316666666666666',
#   'timeMax': '16.333',
#   'timeMin': '8.150'},
#  {'efcvTrfl': '49',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '12:55',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '12.45',
#   'timeMax': '11.783',
#   'timeMin': '8.683'},
#  {'efcvTrfl': '642',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13  ',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '8.783333333333333',
#   'timeMax': '13.300',
#   'timeMin': '6.466'},
#  {'efcvTrfl': '192',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13:00',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '12.35',
#   'timeMax': '13.300',
#   'timeMin': '6.466'},
#  {'efcvTrfl': '61',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13:05',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '11.383333333333333',
#   'timeMax': '13.300',
#   'timeMin': '7.450'},
#  {'efcvTrfl': '53',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13:10',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '10.533333333333333',
#   'timeMax': '10.933',
#   'timeMin': '6.466'},
#  {'efcvTrfl': '178',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13:15',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '10.575',
#   'timeMax': '10.683',
#   'timeMin': '7.150'},
#  {'efcvTrfl': '42',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13:20',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '9.466666666666667',
#   'timeMax': '10.683',
#   'timeMin': '7.150'},
#  {'efcvTrfl': '54',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13:25',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '9.25',
#   'timeMax': '10.583',
#   'timeMin': '7.350'},
#  {'efcvTrfl': '236',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210130',
#   'stdTime': '13:30',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '10.0',
#   'timeMax': '12.050',
#   'timeMin': '8.250'}]

# %%
records = []
for car in cars:
    dic = {}
    dic['date'] = car['stdDate']
    dic['time'] = car['stdTime']
    dic['type'] = car['tcsCarTypeDivName']
    records.append(dic)
records
# Out:
# [{'date': '20210130', 'time': '12:50', 'type': '소형차'},
#  {'date': '20210130', 'time': '12:55', 'type': '소형차'},
#  {'date': '20210130', 'time': '13  ', 'type': '소형차'},
#  {'date': '20210130', 'time': '13:00', 'type': '소형차'},
#  {'date': '20210130', 'time': '13:05', 'type': '소형차'},
#  {'date': '20210130', 'time': '13:10', 'type': '소형차'},
#  {'date': '20210130', 'time': '13:15', 'type': '소형차'},
#  {'date': '20210130', 'time': '13:20', 'type': '소형차'},
#  {'date': '20210130', 'time': '13:25', 'type': '소형차'},
#  {'date': '20210130', 'time': '13:30', 'type': '소형차'}]
